# %%
# Importing Required Libraries
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
#import the csv file

df = pd.read_csv("New Year Sales Data.csv",encoding="unicode_escape")

# %%
df.shape
# Out:
# (11251, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11249 non-null  float64
# dtypes: float64(1), int64(4), object(8)
# memory usage: 1.1+ MB

# %%
df.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders   Amount
# 0     Maharashtra   Western       Healthcare             Auto       1  23952.0
# 1  Andhra Pradesh  Southern             Govt             Auto       3  23934.0
# 2   Uttar Pradesh   Central       Automobile             Auto       3  23924.0
# 3       Karnataka  Southern     Construction             Auto       2  23912.0
# 4         Gujarat   Western  Food Processing             Auto       2  23877.0

# %%
# Check null values
pd.isnull(df).sum()
# Out:
# User_ID             0
# Cust_name           0
# Product_ID          0
# Gender              0
# Age Group           0
# Age                 0
# Marital_Status      0
# State               0
# Zone                0
# Occupation          0
# Product_Category    0
# Orders              0
# Amount              2
# dtype: int64

# %%
#drop null values
df.dropna(inplace=True)

# %%
# Change data type
df['Amount'] = df['Amount'].astype('int')

# %%
df['Amount'].dtypes
# Out:
# dtype('int64')

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
# rename column
df.rename(columns={'Cust_name':'Customer_Name'})
# Out:
#        User_ID Customer_Name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903     Sanskriti  P00125942      F     26-35   28               0
# 1      1000732        Kartik  P00110942      F     26-35   35               1
# 2      1001990         Bindu  P00118542      F     26-35   35               1
# 3      1001425        Sudevi  P00237842      M      0-17   16               0
# 4      1000588          Joni  P00057942      M     26-35   28               1
# ...        ...           ...        ...    ...       ...  ...             ...
# 11246  1000695       Manning  P00296942      M     18-25   19               1
# 11247  1004089   Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209         Oshin  P00201342      F     36-45   40               0
# 11249  1004023        Noonan  P00059442      M     36-45   37               0
# 11250  1002744       Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
# describe() method returns description of the data in the DataFrame (i.e. count, mean, std, etc)
df.describe()
# Out:
#             User_ID           Age  Marital_Status        Orders        Amount
# count  1.124900e+04  11249.000000    11249.000000  11249.000000  11249.000000
# mean   1.003004e+06     35.419593        0.420215      2.489466   9464.030136
# std    1.716014e+03     12.754596        0.493615      1.115048   5231.875156
# min    1.000001e+06     12.000000        0.000000      1.000000    188.000000
# 25%    1.001492e+06     27.000000        0.000000      2.000000   5443.000000
# 50%    1.003065e+06     33.000000        0.000000      2.000000   8110.000000
# 75%    1.004429e+06     43.000000        1.000000      3.000000  12691.000000
# max    1.006040e+06     92.000000        1.000000      4.000000  23952.000000

# %%
# use describe() for specific columns
df[['Marital_Status','Orders','Age']].describe()
# Out:
#        Marital_Status        Orders           Age
# count    11249.000000  11249.000000  11249.000000
# mean         0.420215      2.489466     35.419593
# std          0.493615      1.115048     12.754596
# min          0.000000      1.000000     12.000000
# 25%          0.000000      2.000000     27.000000
# 50%          0.000000      2.000000     33.000000
# 75%          1.000000      3.000000     43.000000
# max          1.000000      4.000000     92.000000

# %% [markdown]
# ***Exploratory Data Analysis***

# %% [markdown]
# **GENDER**

# %%
# Plotting a bar chart for Gender and it's count
px = sns.countplot(x='Gender', hue='Gender',data = df,palette={'F':'m','M':'c'})

for bars in px.containers:
    px.bar_label(bars)

# %%
# Plotting a bar chart for gender vs total Amount

sales_gen = df.groupby(['Gender'], as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False)

sns.barplot(x='Gender', y='Amount', data=sales_gen, hue='Gender',palette={'M':'c','F':'m'})
# Out:
# <Axes: xlabel='Gender', ylabel='Amount'>

# %% [markdown]
# *From above graphs we can see that most of the buyers are females and even the purchasing power of females are greater than men*

# %% [markdown]
# **AGE**

# %%
px = sns.countplot(data = df, x = 'Age Group', hue = 'Gender')

for bars in px.containers:
    px.bar_label(bars)

# %%
# Total Amount vs Age Group
sales_age = df.groupby(['Age Group'], as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False)

sns.barplot(x='Age Group', y='Amount', data=sales_age,hue='Age Group')
# Out:
# <Axes: xlabel='Age Group', ylabel='Amount'>

# %% [markdown]
# *From above graphs we can see that most of the buyers are of age group between 26-35 yrs.*

# %% [markdown]
# **STATE**

# %%
# total Revenue Generated from top 5 states

sales_state = df.groupby(['State'],as_index = False)['Amount'].sum().sort_values(by='Amount',ascending=False).head(5)

sns.barplot(data = sales_state, x = 'State', y = 'Amount', hue = 'State')
# Out:
# <Axes: xlabel='State', ylabel='Amount'>

# %%
# total numbers of orders from top 5 states

sales_state = df.groupby(['State'],as_index = False)['Orders'].sum().sort_values(by='Orders',ascending=False).head(5)

sns.barplot(data = sales_state, x = 'State', y = 'Orders', hue = 'State')
# Out:
# <Axes: xlabel='State', ylabel='Orders'>

# %% [markdown]
# *From above Graphs we can see that maxiumum revenue & most numbers of total from Uttar Pradesh followed by Maharashtra and then Karnataka respectively*

# %% [markdown]
# **MARITAL STATUS**

# %%
px = sns.countplot(data = df , x = 'Marital_Status',hue='Marital_Status')

#sns.set(rc={'figure.figsize':(7,5)})
for bars in px.containers:
    px.bar_label(bars)

# %%
sales_state = df.groupby(['Marital_Status','Gender'], as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False)

#sns.set(rc={'figure.figsize':(6,5)})
sns.barplot(x='Marital_Status',y='Amount',data=sales_state,hue='Gender')
# Out:
# <Axes: xlabel='Marital_Status', ylabel='Amount'>

# %% [markdown]
# *From Above Graphs We can see that most of the buyers are married(Women) and they have high purchasing power*
#
# ***WOMEN For a Reason !!***

# %% [markdown]
# **OCCUPATION**

# %%
sns.set(rc={'figure.figsize':(20,5)})
px = sns.countplot(data = df, x= 'Occupation',hue='Occupation')

for bars in px.containers:
    px.bar_label(bars)

# %%
sales_state = df.groupby(['Occupation'], as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False)

sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data=sales_state,x='Occupation',y='Amount',hue='Occupation')
# Out:
# <Axes: xlabel='Occupation', ylabel='Amount'>

# %% [markdown]
# *From Above Graphs We can see that the most of the Buyers are working in IT Sector followed by Healthcare and Aviation Sector.*

# %% [markdown]
# **PRODUCT CATEGORY**

# %%
sns.set(rc={'figure.figsize':(20,7)})
px = sns.countplot(data = df, x = 'Product_Category',hue='Product_Category')

for bars in px.containers:
    px.bar_label(bars)

# %%
sales_state = df.groupby(['Product_Category'], as_index=False)['Amount'].sum().sort_values(by="Amount",ascending=False).head(5)

sns.set(rc={'figure.figsize':(20,7)})
sns.barplot(data=sales_state,x='Product_Category',y='Amount',hue='Product_Category')
# Out:
# <Axes: xlabel='Product_Category', ylabel='Amount'>

# %% [markdown]
# *From Above Graphs we can see that most of the sold products are from Food,Clothing and Electronics category*

# %% [markdown]
# **PRODUCT_ID**

# %%
sales_state = df.groupby(['Product_ID'],as_index=False)['Orders'].sum().sort_values(by='Orders',ascending=False).head(10)

sns.set({'figure.figsize':(12,7)})
sns.barplot(data=sales_state,x='Product_ID',y='Orders',hue='Orders')
# Out:
# <Axes: xlabel='Product_ID', ylabel='Orders'>

# %% [markdown]
# ****CONCLUSION****

# %% [markdown]
# ***Married Woman Betwwen 26-35 years from UP,Maharashtra and Karnataka who are working in IT Sector, Healthcare & Aviation Industry are more likely to spent on Food , Clothing and Elecronics from all the categories.***
